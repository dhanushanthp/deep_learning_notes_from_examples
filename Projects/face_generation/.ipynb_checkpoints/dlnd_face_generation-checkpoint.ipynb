# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# /Users/dhanushanthp/anaconda3/envs/dlnd/lib/python3.5/site-packages/ipykernel/__main__.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests


def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_input = tf.placeholder(
        dtype=tf.float32,
        shape=(None, image_width, image_height, image_channels),
        name='input_real')
    
    z_input = tf.placeholder(
        dtype=tf.float32, shape=(None, z_dim), name='input_z')
    
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')

    return real_input, z_input, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    alpha = 0.2
    with tf.variable_scope('discriminator', reuse=reuse):
        # 28X28X3
        x1 = tf.layers.conv2d(images, 32, 3, strides=2, padding='same')
        nor1 = tf.layers.batch_normalization(x1, training=True)
        relu1 = tf.maximum(alpha * nor1, nor1)
        # 14X14X32
        
        x1_ = tf.layers.conv2d(relu1, 64, 3, strides=1, padding='same')
        nor2_ = tf.layers.batch_normalization(x1_, training=True)
        relu2_ = tf.maximum(alpha * nor2_, nor2_)
        # 14X14X64
        
        x2 = tf.layers.conv2d(relu2_, 128, 3, strides=2, padding='same')
        nor2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(alpha * nor2, nor2)
        # 7X7X64
        
        x3 = tf.layers.conv2d(relu2, 256, 3, strides=2, padding='same')
        nor3 = tf.layers.batch_normalization(x3, training=True)
        relu3 = tf.maximum(alpha * nor3, nor3)
        # 4 X 4 X 128, because the ceil will max the 3.5 to 4 in output height calculation
        
        x4 = tf.layers.conv2d(relu3, 512, 3, strides=2, padding='same')
        nor4 = tf.layers.batch_normalization(x4, training=True)
        relu4 = tf.maximum(alpha * nor4, nor4)
        # 2X2X256
        
        flat = tf.reshape(relu4, (-1, 2 * 2* 512))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)

    return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    
    1. The z comes as noise vector. And that need to be passed in to fully connected layer.
    2. reshape the vector in to multi dim matrix.
    
    output = input * stride + max(filter - stride, 0)  # VALID
    output = input * stride  # SAME
    """
    # TODO: Implement Function
    alpha = 0.2
    with tf.variable_scope('generator', reuse=not is_train):
        x = tf.layers.dense(z, 3*3*512)
        
        x = tf.reshape(x, (-1, 3, 3, 512))
        nor = tf.layers.batch_normalization(x, training=is_train)
        relu = tf.maximum(alpha * nor, nor)
        
        x1_ = tf.layers.conv2d_transpose(relu, 256, 3, strides=2, padding='valid')
        nor1_ = tf.layers.batch_normalization(x1_, training=is_train)
        relu1_ = tf.maximum(alpha * nor1_, nor1_)
        # 7, 7, 256
        
        # Having a addtional layer with same size.
        x1 = tf.layers.conv2d_transpose(relu1_, 128, 3, strides=1, padding='same')
        nor1 = tf.layers.batch_normalization(x1, training=is_train)
        relu1 = tf.maximum(alpha * nor1, nor1)
        # 7, 7, 128        
        
        x2 = tf.layers.conv2d_transpose(relu1, 64, 3, strides=2, padding='same')
        nor2 = tf.layers.batch_normalization(x2, training=is_train)
        relu2 = tf.maximum(alpha * nor2, nor2)
        # 14, 14, 64
        
        x3 = tf.layers.conv2d_transpose(relu2, 32, 3, strides=2, padding='same')
        nor3 = tf.layers.batch_normalization(x3, training=is_train)
        relu3 = tf.maximum(alpha * nor3, nor3)
        # 28, 28, 32
            
        logits = tf.layers.conv2d_transpose(relu2, out_channel_dim, 3, strides=2, padding='same')
        
        out = tf.tanh(logits)
        
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_real_model, d_real_logits = discriminator(input_real)
    # Use the same weights in for discriminator
    d_noise_model, d_noise_logits = discriminator(g_model, reuse=True)

    d_real_lose = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=d_real_logits, labels=tf.ones_like(d_real_logits) * 0.9))

    d_noise_lose = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=d_noise_logits, labels=tf.zeros_like(d_noise_logits)))

    d_total_lose = d_real_lose + d_noise_lose

    # logits from discriminator.
    g_lose = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=d_noise_logits, labels=tf.ones_like(d_noise_logits)))

    return d_total_lose, g_lose


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    train_vars = tf.trainable_variables()
    dis_vars = [var for var in train_vars if var.name.startswith('discriminator')]
    gen_vars = [var for var in train_vars if var.name.startswith('generator')]
    
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    gen_updates = [op for op in update_ops if op.name.startswith('generator')]
    
    with tf.control_dependencies(gen_updates):
        dis_train_ops = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=dis_vars)
        gen_train_ops = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=gen_vars)
    
        return dis_train_ops, gen_train_ops


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    _, image_width, image_height, image_channels = data_shape
    
    input_real, input_z, in_learning_rate = model_inputs(image_width, image_height, image_channels, z_dim)
    dis_loss, gen_loss = model_loss(input_real, input_z, image_channels)
    dis_ops, gen_ops = model_opt(dis_loss, gen_loss, learning_rate, beta1)
    
    steps = 0
    
    print_every = 10
    show_every = 100
    
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                steps += 1
                
                batch_images *= 2
                
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                _ = sess.run(dis_ops, feed_dict={ input_real: batch_images, input_z: batch_z, in_learning_rate: learning_rate })
                _ = sess.run(gen_ops, feed_dict={ input_z: batch_z, in_learning_rate: learning_rate })
                
                if steps % print_every == 0:
                    dis_loss_train = dis_loss.eval({
                        input_z: batch_z,
                        input_real: batch_images
                    })
                    gen_loss_train = gen_loss.eval({
                        input_z: batch_z
                    })
                    
                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                         "Discriminator Loss: {:.4f}...".format(dis_loss_train),
                         "Generator Loss: {:.4f}".format(gen_loss_train))
                    
                if steps % show_every == 0:
                    show_generator_output(sess, 25, input_z, image_channels, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 128
learning_rate = 0.001
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.6662... Generator Loss: 7.6219
# Epoch 1/2... Discriminator Loss: 1.5707... Generator Loss: 15.5973
# Epoch 1/2... Discriminator Loss: 1.0660... Generator Loss: 6.9459
# Epoch 1/2... Discriminator Loss: 0.5001... Generator Loss: 4.5377
# Epoch 1/2... Discriminator Loss: 0.6573... Generator Loss: 4.5368
# Epoch 1/2... Discriminator Loss: 0.6178... Generator Loss: 1.7237
# Epoch 1/2... Discriminator Loss: 0.6777... Generator Loss: 3.0656
# Epoch 1/2... Discriminator Loss: 0.8161... Generator Loss: 1.6190
# Epoch 1/2... Discriminator Loss: 1.0801... Generator Loss: 0.9471
# Epoch 1/2... Discriminator Loss: 0.8850... Generator Loss: 1.3532
# Epoch 1/2... Discriminator Loss: 1.1619... Generator Loss: 0.8193
# Epoch 1/2... Discriminator Loss: 0.8218... Generator Loss: 1.2909
# Epoch 1/2... Discriminator Loss: 0.8781... Generator Loss: 2.3767
# Epoch 1/2... Discriminator Loss: 0.9969... Generator Loss: 2.7731
# Epoch 1/2... Discriminator Loss: 1.0237... Generator Loss: 1.7216
# Epoch 1/2... Discriminator Loss: 0.8664... Generator Loss: 1.1290
# Epoch 1/2... Discriminator Loss: 1.2035... Generator Loss: 3.1641
# Epoch 1/2... Discriminator Loss: 1.6788... Generator Loss: 0.3858
# Epoch 1/2... Discriminator Loss: 1.0360... Generator Loss: 2.9742
# Epoch 1/2... Discriminator Loss: 1.0809... Generator Loss: 0.7790
# Epoch 1/2... Discriminator Loss: 1.0704... Generator Loss: 0.9016
# Epoch 1/2... Discriminator Loss: 0.8649... Generator Loss: 1.1662
# Epoch 1/2... Discriminator Loss: 0.8182... Generator Loss: 2.0755
# Epoch 1/2... Discriminator Loss: 1.8537... Generator Loss: 4.4416
# Epoch 1/2... Discriminator Loss: 0.8842... Generator Loss: 1.1226
# Epoch 1/2... Discriminator Loss: 1.2316... Generator Loss: 0.6060
# Epoch 1/2... Discriminator Loss: 1.3646... Generator Loss: 0.5114
# Epoch 1/2... Discriminator Loss: 0.7540... Generator Loss: 2.6914
# Epoch 1/2... Discriminator Loss: 1.0563... Generator Loss: 0.7713
# Epoch 1/2... Discriminator Loss: 1.0142... Generator Loss: 0.8833
# Epoch 1/2... Discriminator Loss: 1.6073... Generator Loss: 0.3995
# Epoch 1/2... Discriminator Loss: 0.9292... Generator Loss: 0.9246
# Epoch 1/2... Discriminator Loss: 1.4098... Generator Loss: 0.4862
# Epoch 1/2... Discriminator Loss: 1.5044... Generator Loss: 0.4320
# Epoch 1/2... Discriminator Loss: 1.4999... Generator Loss: 0.5275
# Epoch 1/2... Discriminator Loss: 0.9299... Generator Loss: 1.1552
# Epoch 1/2... Discriminator Loss: 0.9630... Generator Loss: 1.1013
# Epoch 1/2... Discriminator Loss: 1.0405... Generator Loss: 0.7726
# Epoch 1/2... Discriminator Loss: 1.0820... Generator Loss: 0.7276
# Epoch 1/2... Discriminator Loss: 2.0357... Generator Loss: 3.3530
# Epoch 1/2... Discriminator Loss: 1.1959... Generator Loss: 0.6464
# Epoch 1/2... Discriminator Loss: 0.9357... Generator Loss: 1.2893
# Epoch 1/2... Discriminator Loss: 1.1054... Generator Loss: 1.6839
# Epoch 1/2... Discriminator Loss: 0.9571... Generator Loss: 1.1211
# Epoch 1/2... Discriminator Loss: 1.4867... Generator Loss: 0.4621
# Epoch 1/2... Discriminator Loss: 1.0294... Generator Loss: 2.1508
# Epoch 1/2... Discriminator Loss: 0.8869... Generator Loss: 1.2036
# Epoch 1/2... Discriminator Loss: 1.0234... Generator Loss: 2.8522
# Epoch 1/2... Discriminator Loss: 0.8711... Generator Loss: 1.1069
# Epoch 1/2... Discriminator Loss: 1.1064... Generator Loss: 0.7501
# Epoch 1/2... Discriminator Loss: 0.8401... Generator Loss: 2.3769
# Epoch 1/2... Discriminator Loss: 1.8628... Generator Loss: 0.2946
# Epoch 1/2... Discriminator Loss: 0.9593... Generator Loss: 0.9518
# Epoch 1/2... Discriminator Loss: 1.0892... Generator Loss: 0.7371
# Epoch 1/2... Discriminator Loss: 0.9231... Generator Loss: 1.0492
# Epoch 1/2... Discriminator Loss: 0.8509... Generator Loss: 1.7030
# Epoch 1/2... Discriminator Loss: 0.8688... Generator Loss: 1.0103
# Epoch 1/2... Discriminator Loss: 0.9710... Generator Loss: 0.8231
# Epoch 1/2... Discriminator Loss: 0.8970... Generator Loss: 0.9996
# Epoch 1/2... Discriminator Loss: 0.7878... Generator Loss: 1.1295
# Epoch 1/2... Discriminator Loss: 1.2941... Generator Loss: 0.5914
# Epoch 1/2... Discriminator Loss: 1.5883... Generator Loss: 2.4087
# Epoch 1/2... Discriminator Loss: 1.0725... Generator Loss: 0.7140
# Epoch 1/2... Discriminator Loss: 0.8967... Generator Loss: 0.9440
# Epoch 1/2... Discriminator Loss: 0.7452... Generator Loss: 1.1954
# Epoch 1/2... Discriminator Loss: 0.7512... Generator Loss: 1.2247
# Epoch 1/2... Discriminator Loss: 0.8254... Generator Loss: 1.3182
# Epoch 1/2... Discriminator Loss: 0.7468... Generator Loss: 1.3521
# Epoch 1/2... Discriminator Loss: 0.8889... Generator Loss: 1.0200
# Epoch 1/2... Discriminator Loss: 0.6572... Generator Loss: 2.1762
# Epoch 1/2... Discriminator Loss: 0.8724... Generator Loss: 0.9836
# Epoch 1/2... Discriminator Loss: 0.7011... Generator Loss: 1.4400
# Epoch 1/2... Discriminator Loss: 0.9960... Generator Loss: 0.8900
# Epoch 1/2... Discriminator Loss: 1.0205... Generator Loss: 0.7758
# Epoch 1/2... Discriminator Loss: 0.9781... Generator Loss: 2.1587
# Epoch 1/2... Discriminator Loss: 0.7264... Generator Loss: 1.2380
# Epoch 1/2... Discriminator Loss: 1.2027... Generator Loss: 4.5342
# Epoch 1/2... Discriminator Loss: 0.6339... Generator Loss: 1.4192
# Epoch 1/2... Discriminator Loss: 1.0009... Generator Loss: 2.0928
# Epoch 1/2... Discriminator Loss: 0.9590... Generator Loss: 0.8391
# Epoch 1/2... Discriminator Loss: 0.6251... Generator Loss: 1.5255
# Epoch 1/2... Discriminator Loss: 0.8220... Generator Loss: 1.1244
# Epoch 1/2... Discriminator Loss: 0.8547... Generator Loss: 1.0216
# Epoch 1/2... Discriminator Loss: 0.6165... Generator Loss: 1.5547
# Epoch 1/2... Discriminator Loss: 0.5511... Generator Loss: 2.4668
# Epoch 1/2... Discriminator Loss: 1.9158... Generator Loss: 0.3373
# Epoch 1/2... Discriminator Loss: 0.7784... Generator Loss: 1.8614
# Epoch 1/2... Discriminator Loss: 1.3921... Generator Loss: 0.5860
# Epoch 1/2... Discriminator Loss: 0.9134... Generator Loss: 1.0543
# Epoch 1/2... Discriminator Loss: 0.9626... Generator Loss: 0.8667
# Epoch 1/2... Discriminator Loss: 1.0889... Generator Loss: 0.7728
# Epoch 1/2... Discriminator Loss: 1.3006... Generator Loss: 3.1209
# Epoch 1/2... Discriminator Loss: 0.7404... Generator Loss: 1.3538
# Epoch 2/2... Discriminator Loss: 0.7741... Generator Loss: 1.5081
# Epoch 2/2... Discriminator Loss: 1.0249... Generator Loss: 0.7668
# Epoch 2/2... Discriminator Loss: 0.5522... Generator Loss: 1.9558
# Epoch 2/2... Discriminator Loss: 0.6022... Generator Loss: 1.6312
# Epoch 2/2... Discriminator Loss: 0.9960... Generator Loss: 0.8464
# Epoch 2/2... Discriminator Loss: 0.7290... Generator Loss: 1.2452
# Epoch 2/2... Discriminator Loss: 0.6321... Generator Loss: 1.9047
# Epoch 2/2... Discriminator Loss: 0.7637... Generator Loss: 1.4288
# Epoch 2/2... Discriminator Loss: 0.7159... Generator Loss: 1.2949
# Epoch 2/2... Discriminator Loss: 1.3469... Generator Loss: 0.5982
# Epoch 2/2... Discriminator Loss: 0.6030... Generator Loss: 1.8501
# Epoch 2/2... Discriminator Loss: 0.5967... Generator Loss: 1.5951
# Epoch 2/2... Discriminator Loss: 1.3065... Generator Loss: 0.5999
# Epoch 2/2... Discriminator Loss: 0.4521... Generator Loss: 2.4993
# Epoch 2/2... Discriminator Loss: 0.7317... Generator Loss: 1.2758
# Epoch 2/2... Discriminator Loss: 1.1473... Generator Loss: 0.7321
# Epoch 2/2... Discriminator Loss: 0.9762... Generator Loss: 2.2720
# Epoch 2/2... Discriminator Loss: 0.7613... Generator Loss: 1.6923
# Epoch 2/2... Discriminator Loss: 0.7917... Generator Loss: 2.1558
# Epoch 2/2... Discriminator Loss: 1.0115... Generator Loss: 0.8623
# Epoch 2/2... Discriminator Loss: 0.8150... Generator Loss: 1.2245
# Epoch 2/2... Discriminator Loss: 0.6950... Generator Loss: 1.8154
# Epoch 2/2... Discriminator Loss: 0.9106... Generator Loss: 0.9740
# Epoch 2/2... Discriminator Loss: 0.8407... Generator Loss: 1.2674
# Epoch 2/2... Discriminator Loss: 0.8712... Generator Loss: 2.0873
# Epoch 2/2... Discriminator Loss: 0.8866... Generator Loss: 0.9562
# Epoch 2/2... Discriminator Loss: 0.6230... Generator Loss: 2.2118
# Epoch 2/2... Discriminator Loss: 0.5564... Generator Loss: 1.8914
# Epoch 2/2... Discriminator Loss: 0.7142... Generator Loss: 1.5344
# Epoch 2/2... Discriminator Loss: 0.7715... Generator Loss: 1.2111
# Epoch 2/2... Discriminator Loss: 1.1477... Generator Loss: 0.6896
# Epoch 2/2... Discriminator Loss: 1.0512... Generator Loss: 0.7876
# Epoch 2/2... Discriminator Loss: 0.9261... Generator Loss: 0.8931
# Epoch 2/2... Discriminator Loss: 0.5534... Generator Loss: 1.7742
# Epoch 2/2... Discriminator Loss: 2.8463... Generator Loss: 0.1886
# Epoch 2/2... Discriminator Loss: 0.6339... Generator Loss: 1.6210
# Epoch 2/2... Discriminator Loss: 0.5593... Generator Loss: 2.7121
# Epoch 2/2... Discriminator Loss: 0.4938... Generator Loss: 2.2478
# Epoch 2/2... Discriminator Loss: 1.2186... Generator Loss: 0.8468
# Epoch 2/2... Discriminator Loss: 0.5957... Generator Loss: 2.0692
# Epoch 2/2... Discriminator Loss: 0.5140... Generator Loss: 1.9704
# Epoch 2/2... Discriminator Loss: 0.4361... Generator Loss: 2.8859
# Epoch 2/2... Discriminator Loss: 0.4263... Generator Loss: 3.3782
# Epoch 2/2... Discriminator Loss: 0.9581... Generator Loss: 0.8709
# Epoch 2/2... Discriminator Loss: 0.6981... Generator Loss: 1.3088
# Epoch 2/2... Discriminator Loss: 0.6292... Generator Loss: 1.4813
# Epoch 2/2... Discriminator Loss: 1.1780... Generator Loss: 0.7517
# Epoch 2/2... Discriminator Loss: 0.6007... Generator Loss: 1.7541
# Epoch 2/2... Discriminator Loss: 0.6383... Generator Loss: 2.3662
# Epoch 2/2... Discriminator Loss: 0.5016... Generator Loss: 2.1141
# Epoch 2/2... Discriminator Loss: 0.9307... Generator Loss: 2.9780
# Epoch 2/2... Discriminator Loss: 0.7731... Generator Loss: 1.1199
# Epoch 2/2... Discriminator Loss: 1.7982... Generator Loss: 0.4335
# Epoch 2/2... Discriminator Loss: 0.7343... Generator Loss: 1.9424
# Epoch 2/2... Discriminator Loss: 0.6186... Generator Loss: 1.5523
# Epoch 2/2... Discriminator Loss: 1.0876... Generator Loss: 0.7315
# Epoch 2/2... Discriminator Loss: 0.5758... Generator Loss: 2.6171
# Epoch 2/2... Discriminator Loss: 0.6475... Generator Loss: 1.4798
# Epoch 2/2... Discriminator Loss: 1.7320... Generator Loss: 0.6147
# Epoch 2/2... Discriminator Loss: 0.7693... Generator Loss: 2.1615
# Epoch 2/2... Discriminator Loss: 0.9060... Generator Loss: 1.0044
# Epoch 2/2... Discriminator Loss: 0.5120... Generator Loss: 1.9303
# Epoch 2/2... Discriminator Loss: 0.6026... Generator Loss: 1.7321
# Epoch 2/2... Discriminator Loss: 0.5636... Generator Loss: 1.8672
# Epoch 2/2... Discriminator Loss: 0.6389... Generator Loss: 1.4426
# Epoch 2/2... Discriminator Loss: 0.5170... Generator Loss: 2.1486
# Epoch 2/2... Discriminator Loss: 0.4694... Generator Loss: 2.2522
# Epoch 2/2... Discriminator Loss: 0.4052... Generator Loss: 3.3405
# Epoch 2/2... Discriminator Loss: 0.5926... Generator Loss: 1.7262
# Epoch 2/2... Discriminator Loss: 0.5720... Generator Loss: 1.6691
# Epoch 2/2... Discriminator Loss: 0.4454... Generator Loss: 2.3832
# Epoch 2/2... Discriminator Loss: 0.8486... Generator Loss: 1.0036
# Epoch 2/2... Discriminator Loss: 2.0791... Generator Loss: 0.4338
# Epoch 2/2... Discriminator Loss: 0.9222... Generator Loss: 2.2729
# Epoch 2/2... Discriminator Loss: 0.6475... Generator Loss: 1.7028
# Epoch 2/2... Discriminator Loss: 0.8267... Generator Loss: 1.1017
# Epoch 2/2... Discriminator Loss: 0.6447... Generator Loss: 1.5831
# Epoch 2/2... Discriminator Loss: 0.6330... Generator Loss: 1.6013
# Epoch 2/2... Discriminator Loss: 0.4668... Generator Loss: 2.3201
# Epoch 2/2... Discriminator Loss: 0.5163... Generator Loss: 2.1208
# Epoch 2/2... Discriminator Loss: 0.8224... Generator Loss: 1.0924
# Epoch 2/2... Discriminator Loss: 0.5727... Generator Loss: 1.6867
# Epoch 2/2... Discriminator Loss: 0.5642... Generator Loss: 2.3345
# Epoch 2/2... Discriminator Loss: 0.5106... Generator Loss: 2.4419
# Epoch 2/2... Discriminator Loss: 0.5733... Generator Loss: 1.7081
# Epoch 2/2... Discriminator Loss: 0.8186... Generator Loss: 1.0571
# Epoch 2/2... Discriminator Loss: 0.6976... Generator Loss: 1.3612
# Epoch 2/2... Discriminator Loss: 0.7410... Generator Loss: 1.2882
# Epoch 2/2... Discriminator Loss: 0.7678... Generator Loss: 1.3555
# Epoch 2/2... Discriminator Loss: 0.4289... Generator Loss: 2.6868
# Epoch 2/2... Discriminator Loss: 1.3788... Generator Loss: 0.6093
# Epoch 2/2... Discriminator Loss: 0.5384... Generator Loss: 1.9090
# Epoch 2/2... Discriminator Loss: 0.5184... Generator Loss: 2.0785
# Epoch 2/2... Discriminator Loss: 0.9126... Generator Loss: 0.9467

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0001
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.5133... Generator Loss: 2.3077
# Epoch 1/1... Discriminator Loss: 0.4673... Generator Loss: 2.5652
# Epoch 1/1... Discriminator Loss: 0.4720... Generator Loss: 2.5064
# Epoch 1/1... Discriminator Loss: 0.3981... Generator Loss: 3.5799
# Epoch 1/1... Discriminator Loss: 0.3842... Generator Loss: 3.6245
# Epoch 1/1... Discriminator Loss: 0.3753... Generator Loss: 4.8034
# Epoch 1/1... Discriminator Loss: 0.3726... Generator Loss: 4.6197
# Epoch 1/1... Discriminator Loss: 0.3663... Generator Loss: 3.8092
# Epoch 1/1... Discriminator Loss: 0.3811... Generator Loss: 3.4466
# Epoch 1/1... Discriminator Loss: 0.3652... Generator Loss: 4.1415
# Epoch 1/1... Discriminator Loss: 0.3765... Generator Loss: 3.6947
# Epoch 1/1... Discriminator Loss: 0.3486... Generator Loss: 5.4479
# Epoch 1/1... Discriminator Loss: 0.3581... Generator Loss: 4.1033
# Epoch 1/1... Discriminator Loss: 0.3653... Generator Loss: 3.9263
# Epoch 1/1... Discriminator Loss: 1.5235... Generator Loss: 11.7551
# Epoch 1/1... Discriminator Loss: 0.3597... Generator Loss: 4.3614
# Epoch 1/1... Discriminator Loss: 0.3652... Generator Loss: 4.2082
# Epoch 1/1... Discriminator Loss: 0.3775... Generator Loss: 3.9304
# Epoch 1/1... Discriminator Loss: 1.1321... Generator Loss: 10.0799
# Epoch 1/1... Discriminator Loss: 0.4119... Generator Loss: 3.3378
# Epoch 1/1... Discriminator Loss: 0.4307... Generator Loss: 2.9380
# Epoch 1/1... Discriminator Loss: 0.4121... Generator Loss: 3.3534
# Epoch 1/1... Discriminator Loss: 0.5483... Generator Loss: 1.9304
# Epoch 1/1... Discriminator Loss: 0.5009... Generator Loss: 2.3553
# Epoch 1/1... Discriminator Loss: 0.4299... Generator Loss: 2.9339
# Epoch 1/1... Discriminator Loss: 0.3850... Generator Loss: 3.7883
# Epoch 1/1... Discriminator Loss: 0.4466... Generator Loss: 4.3624
# Epoch 1/1... Discriminator Loss: 0.4580... Generator Loss: 2.7375
# Epoch 1/1... Discriminator Loss: 0.4732... Generator Loss: 3.5505
# Epoch 1/1... Discriminator Loss: 0.4646... Generator Loss: 3.2036
# Epoch 1/1... Discriminator Loss: 0.4550... Generator Loss: 2.7588
# Epoch 1/1... Discriminator Loss: 0.4522... Generator Loss: 2.6203
# Epoch 1/1... Discriminator Loss: 0.6892... Generator Loss: 1.8924
# Epoch 1/1... Discriminator Loss: 0.8352... Generator Loss: 6.8949
# Epoch 1/1... Discriminator Loss: 0.6036... Generator Loss: 4.9382
# Epoch 1/1... Discriminator Loss: 0.4857... Generator Loss: 2.2897
# Epoch 1/1... Discriminator Loss: 0.4323... Generator Loss: 3.4205
# Epoch 1/1... Discriminator Loss: 0.5419... Generator Loss: 1.9696
# Epoch 1/1... Discriminator Loss: 0.4068... Generator Loss: 4.4252
# Epoch 1/1... Discriminator Loss: 0.6406... Generator Loss: 1.5813
# Epoch 1/1... Discriminator Loss: 0.4303... Generator Loss: 2.8849
# Epoch 1/1... Discriminator Loss: 0.4872... Generator Loss: 3.9017
# Epoch 1/1... Discriminator Loss: 0.4759... Generator Loss: 3.2587
# Epoch 1/1... Discriminator Loss: 0.4803... Generator Loss: 3.7810
# Epoch 1/1... Discriminator Loss: 0.4982... Generator Loss: 2.5364
# Epoch 1/1... Discriminator Loss: 0.7352... Generator Loss: 1.3665
# Epoch 1/1... Discriminator Loss: 0.5205... Generator Loss: 2.6755
# Epoch 1/1... Discriminator Loss: 0.8123... Generator Loss: 1.2594
# Epoch 1/1... Discriminator Loss: 0.6138... Generator Loss: 1.6869
# Epoch 1/1... Discriminator Loss: 0.4962... Generator Loss: 3.6127
# Epoch 1/1... Discriminator Loss: 0.4798... Generator Loss: 2.8538
# Epoch 1/1... Discriminator Loss: 0.5426... Generator Loss: 2.8855
# Epoch 1/1... Discriminator Loss: 0.4640... Generator Loss: 2.6619
# Epoch 1/1... Discriminator Loss: 0.5155... Generator Loss: 2.4599
# Epoch 1/1... Discriminator Loss: 0.5510... Generator Loss: 2.0709
# Epoch 1/1... Discriminator Loss: 0.4681... Generator Loss: 2.5359
# Epoch 1/1... Discriminator Loss: 0.6231... Generator Loss: 3.1886
# Epoch 1/1... Discriminator Loss: 0.6497... Generator Loss: 1.6414
# Epoch 1/1... Discriminator Loss: 0.4941... Generator Loss: 2.4449
# Epoch 1/1... Discriminator Loss: 0.4859... Generator Loss: 2.3996
# Epoch 1/1... Discriminator Loss: 0.5213... Generator Loss: 2.7458
# Epoch 1/1... Discriminator Loss: 0.6363... Generator Loss: 3.0583
# Epoch 1/1... Discriminator Loss: 0.6354... Generator Loss: 1.6038
# Epoch 1/1... Discriminator Loss: 0.6028... Generator Loss: 1.7672
# Epoch 1/1... Discriminator Loss: 0.7303... Generator Loss: 4.0247
# Epoch 1/1... Discriminator Loss: 0.5271... Generator Loss: 2.0298
# Epoch 1/1... Discriminator Loss: 0.7142... Generator Loss: 1.3149
# Epoch 1/1... Discriminator Loss: 0.6033... Generator Loss: 1.8846
# Epoch 1/1... Discriminator Loss: 0.6120... Generator Loss: 1.7705
# Epoch 1/1... Discriminator Loss: 0.4806... Generator Loss: 2.5214
# Epoch 1/1... Discriminator Loss: 0.6416... Generator Loss: 1.6668
# Epoch 1/1... Discriminator Loss: 0.6540... Generator Loss: 1.5450
# Epoch 1/1... Discriminator Loss: 0.5567... Generator Loss: 3.3240
# Epoch 1/1... Discriminator Loss: 0.4980... Generator Loss: 2.3526
# Epoch 1/1... Discriminator Loss: 0.5649... Generator Loss: 1.9858
# Epoch 1/1... Discriminator Loss: 0.5474... Generator Loss: 2.8031
# Epoch 1/1... Discriminator Loss: 0.4923... Generator Loss: 2.5043
# Epoch 1/1... Discriminator Loss: 0.9451... Generator Loss: 0.9804
# Epoch 1/1... Discriminator Loss: 0.8926... Generator Loss: 1.1658
# Epoch 1/1... Discriminator Loss: 0.5830... Generator Loss: 3.3643
# Epoch 1/1... Discriminator Loss: 1.3102... Generator Loss: 5.1902
# Epoch 1/1... Discriminator Loss: 0.5130... Generator Loss: 2.4297
# Epoch 1/1... Discriminator Loss: 0.5352... Generator Loss: 2.3387
# Epoch 1/1... Discriminator Loss: 0.5797... Generator Loss: 2.9983
# Epoch 1/1... Discriminator Loss: 0.8299... Generator Loss: 1.2083
# Epoch 1/1... Discriminator Loss: 0.6136... Generator Loss: 2.1084
# Epoch 1/1... Discriminator Loss: 0.6334... Generator Loss: 2.0153
# Epoch 1/1... Discriminator Loss: 0.5967... Generator Loss: 1.8917
# Epoch 1/1... Discriminator Loss: 0.6171... Generator Loss: 1.7792
# Epoch 1/1... Discriminator Loss: 0.6890... Generator Loss: 1.4933
# Epoch 1/1... Discriminator Loss: 0.6595... Generator Loss: 1.5612
# Epoch 1/1... Discriminator Loss: 0.7377... Generator Loss: 1.3865
# Epoch 1/1... Discriminator Loss: 0.7269... Generator Loss: 1.3850
# Epoch 1/1... Discriminator Loss: 0.8044... Generator Loss: 4.3483
# Epoch 1/1... Discriminator Loss: 0.7145... Generator Loss: 1.4453
# Epoch 1/1... Discriminator Loss: 0.6741... Generator Loss: 1.6879
# Epoch 1/1... Discriminator Loss: 0.7745... Generator Loss: 3.4276
# Epoch 1/1... Discriminator Loss: 0.9028... Generator Loss: 0.9952
# Epoch 1/1... Discriminator Loss: 0.5984... Generator Loss: 2.0630
# Epoch 1/1... Discriminator Loss: 0.5898... Generator Loss: 1.9570
# Epoch 1/1... Discriminator Loss: 0.6328... Generator Loss: 2.5532
# Epoch 1/1... Discriminator Loss: 0.7276... Generator Loss: 1.3939
# Epoch 1/1... Discriminator Loss: 0.6942... Generator Loss: 1.4594
# Epoch 1/1... Discriminator Loss: 0.6892... Generator Loss: 2.5598
# Epoch 1/1... Discriminator Loss: 0.6517... Generator Loss: 2.6471
# Epoch 1/1... Discriminator Loss: 0.6925... Generator Loss: 2.0856
# Epoch 1/1... Discriminator Loss: 0.6025... Generator Loss: 2.4798
# Epoch 1/1... Discriminator Loss: 0.6477... Generator Loss: 1.7336
# Epoch 1/1... Discriminator Loss: 0.5323... Generator Loss: 2.5086
# Epoch 1/1... Discriminator Loss: 0.9513... Generator Loss: 3.5809
# Epoch 1/1... Discriminator Loss: 0.7107... Generator Loss: 1.6185
# Epoch 1/1... Discriminator Loss: 1.1265... Generator Loss: 0.7373
# Epoch 1/1... Discriminator Loss: 0.6487... Generator Loss: 2.0365
# Epoch 1/1... Discriminator Loss: 0.6423... Generator Loss: 1.7905
# Epoch 1/1... Discriminator Loss: 0.6534... Generator Loss: 1.5757
# Epoch 1/1... Discriminator Loss: 0.8929... Generator Loss: 1.0581
# Epoch 1/1... Discriminator Loss: 0.6766... Generator Loss: 1.7138
# Epoch 1/1... Discriminator Loss: 0.6794... Generator Loss: 1.5454
# Epoch 1/1... Discriminator Loss: 0.6430... Generator Loss: 1.7901
# Epoch 1/1... Discriminator Loss: 0.5398... Generator Loss: 2.2697
# Epoch 1/1... Discriminator Loss: 0.5830... Generator Loss: 1.8648
# Epoch 1/1... Discriminator Loss: 0.5953... Generator Loss: 1.9790
# Epoch 1/1... Discriminator Loss: 0.6532... Generator Loss: 1.7090
# Epoch 1/1... Discriminator Loss: 0.8430... Generator Loss: 1.1551
# Epoch 1/1... Discriminator Loss: 0.6768... Generator Loss: 1.6012
# Epoch 1/1... Discriminator Loss: 0.6975... Generator Loss: 2.0153
# Epoch 1/1... Discriminator Loss: 0.6353... Generator Loss: 1.7988
# Epoch 1/1... Discriminator Loss: 0.9714... Generator Loss: 0.9115
# Epoch 1/1... Discriminator Loss: 0.6892... Generator Loss: 1.6126
# Epoch 1/1... Discriminator Loss: 0.6131... Generator Loss: 1.8704
# Epoch 1/1... Discriminator Loss: 0.6959... Generator Loss: 1.6694
# Epoch 1/1... Discriminator Loss: 0.6361... Generator Loss: 1.8352
# Epoch 1/1... Discriminator Loss: 0.9172... Generator Loss: 0.9890
# Epoch 1/1... Discriminator Loss: 0.6466... Generator Loss: 2.1037
# Epoch 1/1... Discriminator Loss: 0.5572... Generator Loss: 2.4210
# Epoch 1/1... Discriminator Loss: 0.5485... Generator Loss: 2.3196
# Epoch 1/1... Discriminator Loss: 0.6393... Generator Loss: 2.2697
# Epoch 1/1... Discriminator Loss: 0.7439... Generator Loss: 3.1984
# Epoch 1/1... Discriminator Loss: 0.6134... Generator Loss: 1.9432
# Epoch 1/1... Discriminator Loss: 1.1004... Generator Loss: 3.1609
# Epoch 1/1... Discriminator Loss: 0.5827... Generator Loss: 2.6601
# Epoch 1/1... Discriminator Loss: 0.5402... Generator Loss: 2.1971
# Epoch 1/1... Discriminator Loss: 0.5859... Generator Loss: 1.9842
# Epoch 1/1... Discriminator Loss: 0.5258... Generator Loss: 2.4024
# Epoch 1/1... Discriminator Loss: 0.5759... Generator Loss: 2.4438
# Epoch 1/1... Discriminator Loss: 0.5376... Generator Loss: 2.6157
# Epoch 1/1... Discriminator Loss: 0.6584... Generator Loss: 1.4916
# Epoch 1/1... Discriminator Loss: 0.5280... Generator Loss: 2.3613
# Epoch 1/1... Discriminator Loss: 0.5946... Generator Loss: 2.1670
# Epoch 1/1... Discriminator Loss: 0.7186... Generator Loss: 3.2166
# Epoch 1/1... Discriminator Loss: 0.5868... Generator Loss: 3.2357
# Epoch 1/1... Discriminator Loss: 0.8256... Generator Loss: 3.0053
# Epoch 1/1... Discriminator Loss: 0.7006... Generator Loss: 2.9911
# Epoch 1/1... Discriminator Loss: 0.5724... Generator Loss: 1.8280
# Epoch 1/1... Discriminator Loss: 0.4991... Generator Loss: 2.4433
# Epoch 1/1... Discriminator Loss: 0.6631... Generator Loss: 1.4805
# Epoch 1/1... Discriminator Loss: 0.6115... Generator Loss: 2.6504
# Epoch 1/1... Discriminator Loss: 0.6145... Generator Loss: 1.8872

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
